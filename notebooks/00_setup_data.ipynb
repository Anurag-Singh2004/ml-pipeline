# %% [markdown]
# ###### Purpose : Download and save raw datasets

# %%
import seaborn as sns
import pandas as pd

#load titanic from seaborn
titanic = sns.load_dataset('titanic')

#save to raw folder
titanic.to_csv('../data/raw/titanic_raw.csv',index=False)

print(f"Titanic saved : {titanic.shape}")
print(titanic.head())
# Out:
# Titanic saved : (891, 15)
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#test our preprocessing pipeline
#import our custom functions

import sys
sys.path.append('..') #add parent folder to path

from src.preprocessing import run_titanic_pipeline

#run entire pipeline in one line
X_train, X_test, y_train, y_test = run_titanic_pipeline('../data/raw/titanic_raw.csv')
# Out:
# Starting Titanic pipeline ...
# ...
# Data loaded successfully
# Shape: 891 rows, 15 columns
# Titanic data cleaned successfully
# Missing values : 0
# Titanic features engineered successfully
# Final shape: (891, 8)
# Columns: ['survived', 'pclass', 'sex', 'age', 'fare', 'family_size', 'embarked_Q', 'embarked_S']
# Features (X): (891, 7), Target (y): (891,)
# Train/Test split :
# X_train: (712, 7)
# X_test: (179, 7)
# y_train: (712,)
# y_test: (179,)
# ...
# Pipeline complete. Ready for modeling
